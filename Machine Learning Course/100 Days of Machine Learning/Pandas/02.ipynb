# %% [markdown]
# Dataframe: Multiple column.
# Series: Singular column.

# %%
import pandas as pd
data = {
        "Name": ["John", "Peter", "Lisa"],
        "Age": [25, 30, 35],
        "Salary": [25000, 30000, 35000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Salary
# 0   John   25   25000
# 1  Peter   30   30000
# 2   Lisa   35   35000

# %%
# Read csv file
csv = pd.read_csv(r"/home/raj/Subodh ML/AI-Machine-Learning/Pandas/test.csv")

csv_df = pd.DataFrame(csv)
csv_df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
# Opening excel file in Pandas
# download library: pip install openpyxl xlrd
excel = pd.read_excel(r"/home/raj/Subodh ML/AI-Machine-Learning/Pandas/excel_sample_1.xls")
excel_df = pd.DataFrame(excel)
excel_df.head(15)
# Out:
#      0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon    Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia     Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
print(excel_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   0           50 non-null     int64
#  1   First Name  50 non-null     object
#  2   Last Name   50 non-null     object
#  3   Gender      50 non-null     object
#  4   Country     50 non-null     object
#  5   Age         50 non-null     int64
#  6   Date        50 non-null     object
#  7   Id          50 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 3.2+ KB
# None

# %%
# describe() method provides various results regarding columns with neumerical values
excel_df.describe()
# Out:
#               0        Age           Id
# count  50.00000  50.000000    50.000000
# mean   25.50000  33.260000  4717.720000
# std    14.57738   8.434163  2391.188783
# min     1.00000  21.000000  1258.000000
# 25%    13.25000  26.250000  2603.750000
# 50%    25.50000  32.000000  3574.000000
# 75%    37.75000  37.750000  6536.250000
# max    50.00000  58.000000  9654.000000

# %%
# find how many null values or missing values are there in the columns
print(excel_df.isnull().sum())
# Out:
# 0             0
# First Name    0
# Last Name     0
# Gender        0
# Country       0
# Age           0
# Date          0
# Id            0
# dtype: int64

# %%
# Counting values of a column
excel_df.value_counts('Age').head(3)
# Out:
# Age
# 26    5
# 28    5
# 37    4
# Name: count, dtype: int64

# %%
# Working wtih diabetes dataset
diabetes_data = pd.read_csv(r"/home/raj/Subodh ML/AI-Machine-Learning/Pandas/diabetes.csv")
diabetes_df = pd.DataFrame(diabetes_data)
diabetes_df.head(12)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
# Count value based on column
diabetes_df.value_counts("Outcome")
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# Group values based on column
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
diabetes_df.notnull().sum()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# column wise mean
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Adding a column
diabetes_df['Year'] = '2024'

# Adding a column from another dataset
diabetes_df['Year'] = csv['Year']

diabetes_df.head(6)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome  Year
# 0                     0.627   50        1  2021
# 1                     0.351   31        0  2021
# 2                     0.672   32        1  2021
# 3                     0.167   21        0  2021
# 4                     2.288   33        1  2021
# 5                     0.201   30        0  2021

# %%
# Removing a row
diabetes_df.drop(index=0, axis=0)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Year
# 1                       0.351   31        0  2021
# ...

# %%
# Remove a column
diabetes_df.drop(columns='Year', axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# print a particular row
# locating a row using the index value
diabetes_df.iloc[3]
# Out:
# Pregnancies                    1.000
# Glucose                       89.000
# BloodPressure                 66.000
# SkinThickness                 23.000
# Insulin                       94.000
# BMI                           28.100
# DiabetesPedigreeFunction       0.167
# Age                           21.000
# Outcome                        0.000
# Year                        2021.000
# Name: 3, dtype: float64

# %%
# Remove column parmanently
diabetes_df = diabetes_df.drop(columns='Year', axis=1)

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Shape represents the row and columns
diabetes_df.shape
# Out:
# (768, 9)

# %%
# locating or showing a particular column
print(diabetes_df.iloc[:, 0].head(4)) # first column
print(diabetes_df.iloc[:, 1].head(4)) # second column
print(diabetes_df.iloc[:,-1].head(4)) # last column
# Out:
# 0    6
# 1    1
# 2    8
# 3    1
# Name: Pregnancies, dtype: int64
# 0    148
# 1     85
# 2    183
# 3     89
# Name: Glucose, dtype: int64
# 0    1
# 1    0
# 2    1
# 3    0
# Name: Outcome, dtype: int64

# %% [markdown]
# #### Correlation
# 1. **Positive correlation**: If one value increases such that corresponding other value also increases is known as positive correlation.
# 2. **Negative correlation**: If one value increases such that corresponding other value decreases is known as negative correlation.

# %%
diabetes_df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...
