# %% [markdown]
# # Load and displaying images
# These are the following popular image processing libraries
#
# 1. Matplotlib (`pip install matplotlib`)
# 2. OpenCV (`pip install opencv-python`)
# 3. PIL (`pip install pillow`)
# 4.

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
image = plt.imread('p1.jpg')
# image

# %%
plt.axis('off')
plt.imshow(image)

# %% [markdown]
# ##

# %% [markdown]
# ## OpenCV

# %%
import cv2
image = cv2.imread('p1.jpg')
# image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # color space conversion 
cv2.imshow('Loaded image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# splitting into three channels

blue, green, red = cv2.split(image)
rgb_normal = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(6, 10))

plt.subplot(2, 2, 1)
plt.imshow(rgb_normal)

plt.subplot(2, 2, 2)
plt.imshow(red, cmap='gray')
plt.title("Red")

plt.subplot(2, 2, 3)
plt.imshow(green, cmap='gray')
plt.title("Green")

plt.subplot(2, 2, 4)
plt.imshow(blue, cmap='gray')
plt.title("Blue")
# Out:
# Text(0.5, 1.0, 'Blue')

# %% [markdown]
# ## Pillow

# %%
from PIL import Image
image = Image.open('p1.jpg')
image.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Color space conversion
